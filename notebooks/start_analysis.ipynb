# %%
import pandas as pd
from scripts.extract_supported_versions import extract_supported_versions
from scripts.extract_frame_size import extract_frame_size

columns_to_keep = [
    "user_agent",
    "js_fingerprint.profile.vendor",
    "tls.extensions",
    "tls.tls_version_record",
    "tls.tls_version_negotiated",
    "tls.ja3",
    "tls.ja3_hash",
    "tls.peetprint_hash",
    "http2.akamai_fingerprint",
    "http2.sent_frames",
    "tcpip.ip.ttl",
    "tcpip.tcp.mss",
    "tcpip.tcp.window",
    "os_prediction.highest",
    "os_prediction.platform_mismatch"
]
# Очищаем датафрейм от лишних
df = pd.read_json('../raw_data/fingerprints_with_os_checked.json', lines=True)
raw_df = df.to_dict(orient='records')
df_exp = pd.json_normalize(raw_df, sep='_')

# Группировка по IP и проверка уникальных user_agents для каждого IP
conflicting_ips = df_exp.groupby('ip')['user_agent'].nunique()
conflicting_ips = conflicting_ips[conflicting_ips > 1]

# Для каждого IP, где есть несколько user_agent, оставим только первую запись
df_cleaned = df_exp[~df_exp['ip'].isin(conflicting_ips.index)]  # Убираем строки с конфликтующими IP
df_cleaned = pd.concat([df_cleaned, df_exp[df_exp['ip'].isin(conflicting_ips.index)].drop_duplicates(subset=['ip'])])

columns_to_keep_normalized = [col.replace(".", "_") for col in columns_to_keep]

data_final = df_cleaned[columns_to_keep_normalized]
data_final.loc[:, "tls_supported_versions"] = data_final['tls_extensions'].apply(extract_supported_versions)
data_final.drop(columns=['tls_extensions'], inplace=True)

display(data_final.head(10))
# Out:
# /tmp/ipykernel_33497/4244364554.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_final.loc[:, "tls_supported_versions"] = data_final['tls_extensions'].apply(extract_supported_versions)
# /tmp/ipykernel_33497/4244364554.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_final.drop(columns=['tls_extensions'], inplace=True)
#                                           user_agent  \
# 0  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109...
# 1  Mozilla/5.0 (Linux; Android 8.0.0; SM-G955U Bu...
# 2  Mozilla/5.0 (compatible; AhrefsBot/7.0; +http:...
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2 like M...
# 4  Mozilla/5.0 (compatible; AhrefsBot/7.0; +http:...
# 5  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 6  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...
# 7  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...
# 8  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 9  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#   js_fingerprint_profile_vendor tls_tls_version_record  \
# 0                         [0, ]                    771
# 1              [0, Google Inc.]                    771
# 2              [0, Google Inc.]                    771
# 3     [0, Apple Computer, Inc.]                    771
# 4              [0, Google Inc.]                    771
# 5              [0, Google Inc.]                    771
# 6     [0, Apple Computer, Inc.]                    771
# 7     [0, Apple Computer, Inc.]                    771
# 8              [0, Google Inc.]                    771
# 9              [0, Google Inc.]                    771
#
#   tls_tls_version_negotiated  \
# 0                        772
# 1                        772
# 2                        772
# 3                        772
# 4                        772
# 5                        772
# 6                        772
# 7                        772
# 8                        772
# 9                        772
#
#                                              tls_ja3  \
# 0  771,4865-4867-4866-49195-49199-52393-52392-491...
# 1  771,4865-4866-4867-49195-49199-49196-49200-523...
# 2  771,4865-4866-4867-49195-49199-49196-49200-523...
# 3  771,4865-4866-4867-49196-49195-52393-49200-491...
# 4  771,4865-4866-4867-49195-49199-49196-49200-523...
# 5  771,4865-4866-4867-49195-49199-49196-49200-523...
# 6  771,4865-4866-4867-49196-49195-52393-49200-491...
# 7  771,4865-4866-4867-49196-49195-52393-49200-491...
# 8  771,4865-4866-4867-49195-49199-49196-49200-523...
# 9  771,4865-4866-4867-49195-49199-49196-49200-523...
#
#                        tls_ja3_hash                tls_peetprint_hash  \
# 0  c279b0189edb9269da7bc43dea5e0c36  fea33d3783ae74d495240377b44baa68
# 1  c9c72924ce9126d09d6688ee2c2b462b  8ad9325e12f531d2983b78860de7b0ec
# 2  9f8f0d3c82a11de7092c04dabcc909ac  d3adf83b0154a3dce2a78ec296fcbfa4
# 3  773906b0efdefa24a7f2b8eb6985bf37  b2bafdc69377086c3416be278fd21121
# 4  043bb5082ab9efb57fa102f13a86a6e0  d3adf83b0154a3dce2a78ec296fcbfa4
# 5  0d69ff451640d67ee8b5122752834766  052336488e42ad64eb9768f5bc03004a
# 6  773906b0efdefa24a7f2b8eb6985bf37  b2bafdc69377086c3416be278fd21121
# 7  773906b0efdefa24a7f2b8eb6985bf37  b2bafdc69377086c3416be278fd21121
# 8  cd08e31494f9531f560d64c695473da9  22a4f858cc83b9144c829ca411948a88
# 9  cd08e31494f9531f560d64c695473da9  22a4f858cc83b9144c829ca411948a88
#
#                             http2_akamai_fingerprint  \
# 0  1:65536,4:131072,5:16384|12517377|3:0:0:201,5:...
# 1  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 2  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 3             2:0,4:2097152,3:100|10485760|0|m,s,p,a
# 4  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 5  1:65536,3:1000,4:6291456,6:262144|15663105|0|m...
# 6             2:0,4:2097152,3:100|10485760|0|m,s,p,a
# 7             2:0,4:2097152,3:100|10485760|0|m,s,p,a
# 8  1:65536,2:0,3:1000,4:6291456,6:262144|15663105...
# 9  1:65536,2:0,3:1000,4:6291456,6:262144|15663105...
#
#                                    http2_sent_frames  tcpip_ip_ttl  \
# 0  [{'frame_type': 'SETTINGS', 'length': 18, 'set...          45.0
# 1  [{'frame_type': 'SETTINGS', 'length': 24, 'set...          46.0
# 2  [{'frame_type': 'SETTINGS', 'length': 24, 'set...          58.0
# 3  [{'frame_type': 'SETTINGS', 'length': 18, 'set...          48.0
# 4  [{'frame_type': 'SETTINGS', 'length': 24, 'set...          58.0
# 5  [{'frame_type': 'SETTINGS', 'length': 24, 'set...          55.0
# 6  [{'frame_type': 'SETTINGS', 'length': 18, 'set...          53.0
# 7  [{'frame_type': 'SETTINGS', 'length': 18, 'set...          53.0
# 8  [{'frame_type': 'SETTINGS', 'length': 30, 'set...          45.0
# 9  [{'frame_type': 'SETTINGS', 'length': 30, 'set...          45.0
#
#    tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 0         1460.0           64240.0                 Linux
# 1         1366.0           59220.0                 Linux
# 2         1460.0           65535.0               Android
# 3         1412.0           65535.0                   iOS
# 4         1460.0           65535.0               Android
# 5         1420.0           65320.0                 Linux
# 6         1460.0           65535.0                   iOS
# 7         1460.0           65535.0                   iOS
# 8         1460.0           64240.0                 Linux
# 9         1460.0           64240.0                 Linux
#
#   os_prediction_platform_mismatch  \
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
# 5                            True
# 6                            True
# 7                            True
# 8                            True
# 9                            True
#
#                               tls_supported_versions
# 0                                 [TLS 1.3, TLS 1.2]
# 1            [TLS_GREASE (0x8a8a), TLS 1.3, TLS 1.2]
# 2            [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]
# 3  [TLS_GREASE (0x3a3a), TLS 1.3, TLS 1.2, TLS 1....
# 4            [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]
# 5  [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2, TLS 1....
# 6  [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2, TLS 1....
# 7  [TLS_GREASE (0x8a8a), TLS 1.3, TLS 1.2, TLS 1....
# 8            [TLS_GREASE (0x1a1a), TLS 1.3, TLS 1.2]
# 9            [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]

# %%
df = data_final
print(df.shape)
print(df.isna().sum())
# Out:
# (6598, 15)
# user_agent                            0
# js_fingerprint_profile_vendor      2968
# tls_tls_version_record                0
# tls_tls_version_negotiated            0
# tls_ja3                               0
# tls_ja3_hash                          0
# tls_peetprint_hash                    0
# http2_akamai_fingerprint              0
# http2_sent_frames                     0
# tcpip_ip_ttl                          6
# tcpip_tcp_mss                         6
# tcpip_tcp_window                      6
# os_prediction_highest                 0
# os_prediction_platform_mismatch    2970
# tls_supported_versions                5
# dtype: int64

# %%
display(df[df['os_prediction_platform_mismatch'].isna()])
# Out:
#                                              user_agent  \
# 732   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 733   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 734   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 735   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 740   Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# ...                                                 ...
# 6939  Mozilla/5.0 (iPhone; CPU iPhone OS 16_0 like M...
# 6968  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 7223  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 7240  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 7309  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
#
#      js_fingerprint_profile_vendor tls_tls_version_record  \
# 732                            NaN                    771
# 733                            NaN                    771
# 734                            NaN                    771
# 735                            NaN                    771
# 740                            NaN                    771
# ...                            ...                    ...
# 6939                           NaN                    771
# 6968                           NaN                    771
# 7223                           NaN                    771
# 7240                           NaN                    771
# 7309                           NaN                    771
#
#      tls_tls_version_negotiated  \
# 732                         772
# 733                         772
# 734                         772
# 735                         772
# 740                         772
# ...                         ...
# 6939                        772
# 6968                        772
# 7223                        772
# 7240                        772
# 7309                        772
#
#                                                 tls_ja3  \
# 732   771,4865-4866-4867-49195-49199-49196-49200-523...
# 733   771,4865-4866-4867-49195-49199-49196-49200-523...
# 734   771,4865-4866-4867-49195-49199-49196-49200-523...
# 735   771,4865-4866-4867-49195-49199-49196-49200-523...
# 740   771,4865-4866-4867-49195-49199-49196-49200-523...
# ...                                                 ...
# 6939  771,4865-4866-4867-49195-49199-49196-49200-523...
# 6968  771,4865-4866-4867-49195-49199-49196-49200-523...
# 7223  771,4865-4866-4867-49195-49199-49196-49200-523...
# 7240  771,4865-4866-4867-49195-49199-49196-49200-523...
# 7309  771,4865-4866-4867-49195-49199-49196-49200-523...
#
#                           tls_ja3_hash                tls_peetprint_hash  \
# 732   ab6d7c76b94901e222ccf068c5347452  8ad9325e12f531d2983b78860de7b0ec
# 733   c8e74cfad72f4e7192e85b48aef8c387  8ad9325e12f531d2983b78860de7b0ec
# 734   4eb607ec303ba63ee8194cd34ae328b7  b8ce945a4d9a7a9b5b6132e3658fe033
# 735   b5634fa2d391896e24c2a70bc7e6d7eb  b8ce945a4d9a7a9b5b6132e3658fe033
# 740   28d4a0fa4211f3c6286fe0f0655f6ffd  8ad9325e12f531d2983b78860de7b0ec
# ...                                ...                               ...
# 6939  a11052b5ac6270650abdc43796c00540  b8ce945a4d9a7a9b5b6132e3658fe033
# 6968  f7ccd19d2ef2820c08e01e139ab6a328  b8ce945a4d9a7a9b5b6132e3658fe033
# 7223  b324d948349b458ac2473c4667955e33  22a4f858cc83b9144c829ca411948a88
# 7240  d537c837a85e43d9cdffac603ee2057a  b8ce945a4d9a7a9b5b6132e3658fe033
# 7309  5ecb59393c00859f0b9cc69ea42e2a8d  b8ce945a4d9a7a9b5b6132e3658fe033
#
#                                http2_akamai_fingerprint  \
# 732   1:65536,2:0,3:1000,4:6291456,6:262144,:2765720...
# 733   1:65536,2:0,3:1000,4:6291456,6:262144,:2554462...
# 734   1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 735   1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 740   1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# ...                                                 ...
# 6939  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 6968  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 7223  1:65536,2:0,3:1000,4:6291456,6:262144|15663105...
# 7240  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 7309  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
#
#                                       http2_sent_frames  tcpip_ip_ttl  \
# 732   [{'frame_type': 'SETTINGS', 'length': 36, 'set...          53.0
# 733   [{'frame_type': 'SETTINGS', 'length': 36, 'set...          53.0
# 734   [{'frame_type': 'SETTINGS', 'length': 24, 'set...         111.0
# 735   [{'frame_type': 'SETTINGS', 'length': 24, 'set...         114.0
# 740   [{'frame_type': 'SETTINGS', 'length': 24, 'set...          48.0
# ...                                                 ...           ...
# 6939  [{'frame_type': 'SETTINGS', 'length': 24, 'set...          46.0
# 6968  [{'frame_type': 'SETTINGS', 'length': 24, 'set...          57.0
# 7223  [{'frame_type': 'SETTINGS', 'length': 30, 'set...          50.0
# 7240  [{'frame_type': 'SETTINGS', 'length': 24, 'set...         108.0
# 7309  [{'frame_type': 'SETTINGS', 'length': 24, 'set...         108.0
#
#       tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 732          1332.0           64240.0                 Linux
# 733          1332.0           64240.0                 Linux
# 734          1460.0           64240.0               Windows
# 735          1412.0           64240.0               Windows
# 740          1460.0           42340.0               Android
# ...             ...               ...                   ...
# 6939         8910.0           35640.0               Android
# 6968         1460.0           64240.0                 Linux
# 7223         1460.0           64240.0               Android
# 7240         1440.0           64240.0               Windows
# 7309         1440.0           64240.0               Windows
#
#      os_prediction_platform_mismatch                   tls_supported_versions
# 732                              NaN  [TLS_GREASE (0x6a6a), TLS 1.3, TLS 1.2]
# 733                              NaN  [TLS_GREASE (0x0a0a), TLS 1.3, TLS 1.2]
# 734                              NaN  [TLS_GREASE (0xcaca), TLS 1.3, TLS 1.2]
# 735                              NaN  [TLS_GREASE (0x0a0a), TLS 1.3, TLS 1.2]
# 740                              NaN  [TLS_GREASE (0x2a2a), TLS 1.3, TLS 1.2]
# ...                              ...                                      ...
# 6939                             NaN  [TLS_GREASE (0x6a6a), TLS 1.3, TLS 1.2]
# 6968                             NaN  [TLS_GREASE (0x0a0a), TLS 1.3, TLS 1.2]
# 7223                             NaN  [TLS_GREASE (0xaaaa), TLS 1.3, TLS 1.2]
# 7240                             NaN  [TLS_GREASE (0xfafa), TLS 1.3, TLS 1.2]
# 7309                             NaN  [TLS_GREASE (0x7a7a), TLS 1.3, TLS 1.2]
#
# [2970 rows x 15 columns]

# %%
print(df['js_fingerprint_profile_vendor'].value_counts())
# Out:
# js_fingerprint_profile_vendor
# [0, Google Inc.]             3026
# [0, Apple Computer, Inc.]     306
# [0, ]                         298
# Name: count, dtype: int64

# %%
# Извлечение первого элемента из каждого массива в столбце
df.loc[:, 'js_fingerprint_profile_vendor'] = df['js_fingerprint_profile_vendor'].apply(lambda x: x[1] if isinstance(x, list) else x)
display(df.head(3))
# Out:
#                                           user_agent  \
# 0  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109...
# 1  Mozilla/5.0 (Linux; Android 8.0.0; SM-G955U Bu...
# 2  Mozilla/5.0 (compatible; AhrefsBot/7.0; +http:...
#
#   js_fingerprint_profile_vendor tls_tls_version_record  \
# 0                                                  771
# 1                   Google Inc.                    771
# 2                   Google Inc.                    771
#
#   tls_tls_version_negotiated  \
# 0                        772
# 1                        772
# 2                        772
#
#                                              tls_ja3  \
# 0  771,4865-4867-4866-49195-49199-52393-52392-491...
# 1  771,4865-4866-4867-49195-49199-49196-49200-523...
# 2  771,4865-4866-4867-49195-49199-49196-49200-523...
#
#                        tls_ja3_hash                tls_peetprint_hash  \
# 0  c279b0189edb9269da7bc43dea5e0c36  fea33d3783ae74d495240377b44baa68
# 1  c9c72924ce9126d09d6688ee2c2b462b  8ad9325e12f531d2983b78860de7b0ec
# 2  9f8f0d3c82a11de7092c04dabcc909ac  d3adf83b0154a3dce2a78ec296fcbfa4
#
#                             http2_akamai_fingerprint  \
# 0  1:65536,4:131072,5:16384|12517377|3:0:0:201,5:...
# 1  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 2  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
#
#                                    http2_sent_frames  tcpip_ip_ttl  \
# 0  [{'frame_type': 'SETTINGS', 'length': 18, 'set...          45.0
# 1  [{'frame_type': 'SETTINGS', 'length': 24, 'set...          46.0
# 2  [{'frame_type': 'SETTINGS', 'length': 24, 'set...          58.0
#
#    tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 0         1460.0           64240.0                 Linux
# 1         1366.0           59220.0                 Linux
# 2         1460.0           65535.0               Android
#
#   os_prediction_platform_mismatch                   tls_supported_versions
# 0                            True                       [TLS 1.3, TLS 1.2]
# 1                            True  [TLS_GREASE (0x8a8a), TLS 1.3, TLS 1.2]
# 2                            True  [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]

# %%
print(df.isna().sum())
df.loc[:, 'http2_sent_frames'] = df['http2_sent_frames'].apply(extract_frame_size)
# Out:
# user_agent                            0
# js_fingerprint_profile_vendor      2968
# tls_tls_version_record                0
# tls_tls_version_negotiated            0
# tls_ja3                               0
# tls_ja3_hash                          0
# tls_peetprint_hash                    0
# http2_akamai_fingerprint              0
# http2_sent_frames                     0
# tcpip_ip_ttl                          6
# tcpip_tcp_mss                         6
# tcpip_tcp_window                      6
# os_prediction_highest                 0
# os_prediction_platform_mismatch    2970
# tls_supported_versions                5
# dtype: int64

# %%
display(df[df['tls_supported_versions'].isna()])
display(df[df['tcpip_tcp_window'].isna()])
display(df[df['tcpip_tcp_mss'].isna()])
# Out:
#                                              user_agent  \
# 190   Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 191   Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 793   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3459  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3460  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#      js_fingerprint_profile_vendor tls_tls_version_record  \
# 190                    Google Inc.                    771
# 191                    Google Inc.                    771
# 793                            NaN                    771
# 3459                           NaN                    771
# 3460                   Google Inc.                    771
#
#      tls_tls_version_negotiated  \
# 190                         771
# 191                         771
# 793                         771
# 3459                        771
# 3460                        771
#
#                                                 tls_ja3  \
# 190   771,49195-49199-49196-49200-52393-52392-49171-...
# 191   771,49195-49199-49196-49200-52393-52392-49171-...
# 793   771,49195-49199-49196-49200-52393-52392-158-15...
# 3459  771,49195-49199-49196-49200-49171-49172-156-15...
# 3460  771,49195-49199-49196-49200-49171-49172-156-15...
#
#                           tls_ja3_hash                tls_peetprint_hash  \
# 190   5e573c9c9f8ba720ef9b18e9fce2e2f7  6e75e96b93bf1cdb1f00953ea9e6899a
# 191   5e573c9c9f8ba720ef9b18e9fce2e2f7  6e75e96b93bf1cdb1f00953ea9e6899a
# 793   85f47a058bd9c3d189fa4ff442d39156  8aeebdbc08e7fe03c9916939c4e2bb15
# 3459  a3663749e98327bbc4b46c7307112627  acc2084bf8cf6ebd622c1e3a0bad731f
# 3460  3f17367e26fcfb6e38d2667af1c9abc2  a6845dc34d5400eb23bac8bab304c01a
#
#                                http2_akamai_fingerprint  \
# 190         1:65536,3:1000,4:6291456|15663105|0|m,a,s,p
# 191         1:65536,3:1000,4:6291456|15663105|0|m,a,s,p
# 793   1:4096,2:0,4:65535,5:16384,:0,3:100,6:65536|00...
# 3459                           4:104857600|00|0|m,a,s,p
# 3460                           4:104857600|00|0|m,a,s,p
#
#                                       http2_sent_frames  tcpip_ip_ttl  \
# 190   [HEADER_TABLE_SIZE = 65536, MAX_CONCURRENT_STR...          51.0
# 191   [HEADER_TABLE_SIZE = 65536, MAX_CONCURRENT_STR...          51.0
# 793   [HEADER_TABLE_SIZE = 4096, ENABLE_PUSH = 0, IN...          52.0
# 3459                  [INITIAL_WINDOW_SIZE = 104857600]         113.0
# 3460                  [INITIAL_WINDOW_SIZE = 104857600]         113.0
#
#       tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 190          1460.0           29200.0                 Linux
# 191          1460.0           29200.0                 Linux
# 793          1311.0           42340.0               Android
# 3459         1380.0           64240.0               Windows
# 3460         1380.0           64240.0               Windows
#
#      os_prediction_platform_mismatch tls_supported_versions
# 190                             True                   None
# 191                             True                   None
# 793                              NaN                   None
# 3459                             NaN                   None
# 3460                            True                   None
#                                              user_agent  \
# 868                                         curl/7.81.0
# 869                                         curl/7.81.0
# 871                                         curl/7.81.0
# 872                                         curl/7.81.0
# 6490  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7363  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#      js_fingerprint_profile_vendor tls_tls_version_record  \
# 868                            NaN                    771
# 869                            NaN                    771
# 871                            NaN                    771
# 872                            NaN                    771
# 6490                   Google Inc.                    771
# 7363                   Google Inc.                    771
#
#      tls_tls_version_negotiated  \
# 868                         772
# 869                         772
# 871                         772
# 872                         772
# 6490                        772
# 7363                        772
#
#                                                 tls_ja3  \
# 868   771,4866-4867-4865-49196-49200-159-52393-52392...
# 869   771,4866-4867-4865-49196-49200-159-52393-52392...
# 871   771,4866-4867-4865-49196-49200-159-52393-52392...
# 872   771,4866-4867-4865-49196-49200-159-52393-52392...
# 6490  771,4865-4866-4867-49195-49199-49196-49200-523...
# 7363  771,4865-4866-4867-49195-49199-49196-49200-523...
#
#                           tls_ja3_hash                tls_peetprint_hash  \
# 868   4ea056e63b7910cbf543f0c095064dfe  551ea4c38754f1085d2b16b947b868ef
# 869   4ea056e63b7910cbf543f0c095064dfe  551ea4c38754f1085d2b16b947b868ef
# 871   4ea056e63b7910cbf543f0c095064dfe  551ea4c38754f1085d2b16b947b868ef
# 872   4ea056e63b7910cbf543f0c095064dfe  551ea4c38754f1085d2b16b947b868ef
# 6490  0ae18052c288c1bd39910255598ed827  67037cd3eea4cb139a4e1b47bd5d77d6
# 7363  0ae18052c288c1bd39910255598ed827  67037cd3eea4cb139a4e1b47bd5d77d6
#
#                                http2_akamai_fingerprint  \
# 868             3:100,4:33554432,2:0|33488897|0|m,p,s,a
# 869             3:100,4:33554432,2:0|33488897|0|m,p,s,a
# 871             3:100,4:33554432,2:0|33488897|0|m,p,s,a
# 872             3:100,4:33554432,2:0|33488897|0|m,p,s,a
# 6490  1:65536,3:1000,4:6291456,6:262144|15663105|0|m...
# 7363  1:65536,3:1000,4:6291456,6:262144|15663105|0|m...
#
#                                       http2_sent_frames  tcpip_ip_ttl  \
# 868   [MAX_CONCURRENT_STREAMS = 100, INITIAL_WINDOW_...           NaN
# 869   [MAX_CONCURRENT_STREAMS = 100, INITIAL_WINDOW_...           NaN
# 871   [MAX_CONCURRENT_STREAMS = 100, INITIAL_WINDOW_...           NaN
# 872   [MAX_CONCURRENT_STREAMS = 100, INITIAL_WINDOW_...           NaN
# 6490  [HEADER_TABLE_SIZE = 65536, MAX_CONCURRENT_STR...           NaN
# 7363  [HEADER_TABLE_SIZE = 65536, MAX_CONCURRENT_STR...           NaN
#
#       tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 868             NaN               NaN                   iOS
# 869             NaN               NaN                   iOS
# 871             NaN               NaN                   iOS
# 872             NaN               NaN                   iOS
# 6490            NaN               NaN                   iOS
# 7363            NaN               NaN                   iOS
#
#      os_prediction_platform_mismatch  \
# 868                              NaN
# 869                              NaN
# 871                              NaN
# 872                              NaN
# 6490                            True
# 7363                            True
#
#                                  tls_supported_versions
# 868                                  [TLS 1.3, TLS 1.2]
# 869                                  [TLS 1.3, TLS 1.2]
# 871                                  [TLS 1.3, TLS 1.2]
# 872                                  [TLS 1.3, TLS 1.2]
# 6490  [TLS_GREASE (0x8a8a), TLS 1.3, TLS 1.2, TLS 1....
# 7363  [TLS_GREASE (0xfafa), TLS 1.3, TLS 1.2, TLS 1....
#                                              user_agent  \
# 868                                         curl/7.81.0
# 869                                         curl/7.81.0
# 871                                         curl/7.81.0
# 872                                         curl/7.81.0
# 6490  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7363  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#      js_fingerprint_profile_vendor tls_tls_version_record  \
# 868                            NaN                    771
# 869                            NaN                    771
# 871                            NaN                    771
# 872                            NaN                    771
# 6490                   Google Inc.                    771
# 7363                   Google Inc.                    771
#
#      tls_tls_version_negotiated  \
# 868                         772
# 869                         772
# 871                         772
# 872                         772
# 6490                        772
# 7363                        772
#
#                                                 tls_ja3  \
# 868   771,4866-4867-4865-49196-49200-159-52393-52392...
# 869   771,4866-4867-4865-49196-49200-159-52393-52392...
# 871   771,4866-4867-4865-49196-49200-159-52393-52392...
# 872   771,4866-4867-4865-49196-49200-159-52393-52392...
# 6490  771,4865-4866-4867-49195-49199-49196-49200-523...
# 7363  771,4865-4866-4867-49195-49199-49196-49200-523...
#
#                           tls_ja3_hash                tls_peetprint_hash  \
# 868   4ea056e63b7910cbf543f0c095064dfe  551ea4c38754f1085d2b16b947b868ef
# 869   4ea056e63b7910cbf543f0c095064dfe  551ea4c38754f1085d2b16b947b868ef
# 871   4ea056e63b7910cbf543f0c095064dfe  551ea4c38754f1085d2b16b947b868ef
# 872   4ea056e63b7910cbf543f0c095064dfe  551ea4c38754f1085d2b16b947b868ef
# 6490  0ae18052c288c1bd39910255598ed827  67037cd3eea4cb139a4e1b47bd5d77d6
# 7363  0ae18052c288c1bd39910255598ed827  67037cd3eea4cb139a4e1b47bd5d77d6
#
#                                http2_akamai_fingerprint  \
# 868             3:100,4:33554432,2:0|33488897|0|m,p,s,a
# 869             3:100,4:33554432,2:0|33488897|0|m,p,s,a
# 871             3:100,4:33554432,2:0|33488897|0|m,p,s,a
# 872             3:100,4:33554432,2:0|33488897|0|m,p,s,a
# 6490  1:65536,3:1000,4:6291456,6:262144|15663105|0|m...
# 7363  1:65536,3:1000,4:6291456,6:262144|15663105|0|m...
#
#                                       http2_sent_frames  tcpip_ip_ttl  \
# 868   [MAX_CONCURRENT_STREAMS = 100, INITIAL_WINDOW_...           NaN
# 869   [MAX_CONCURRENT_STREAMS = 100, INITIAL_WINDOW_...           NaN
# 871   [MAX_CONCURRENT_STREAMS = 100, INITIAL_WINDOW_...           NaN
# 872   [MAX_CONCURRENT_STREAMS = 100, INITIAL_WINDOW_...           NaN
# 6490  [HEADER_TABLE_SIZE = 65536, MAX_CONCURRENT_STR...           NaN
# 7363  [HEADER_TABLE_SIZE = 65536, MAX_CONCURRENT_STR...           NaN
#
#       tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 868             NaN               NaN                   iOS
# 869             NaN               NaN                   iOS
# 871             NaN               NaN                   iOS
# 872             NaN               NaN                   iOS
# 6490            NaN               NaN                   iOS
# 7363            NaN               NaN                   iOS
#
#      os_prediction_platform_mismatch  \
# 868                              NaN
# 869                              NaN
# 871                              NaN
# 872                              NaN
# 6490                            True
# 7363                            True
#
#                                  tls_supported_versions
# 868                                  [TLS 1.3, TLS 1.2]
# 869                                  [TLS 1.3, TLS 1.2]
# 871                                  [TLS 1.3, TLS 1.2]
# 872                                  [TLS 1.3, TLS 1.2]
# 6490  [TLS_GREASE (0x8a8a), TLS 1.3, TLS 1.2, TLS 1....
# 7363  [TLS_GREASE (0xfafa), TLS 1.3, TLS 1.2, TLS 1....

# %%
display(df.head(5))
# Out:
#                                           user_agent  \
# 0  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109...
# 1  Mozilla/5.0 (Linux; Android 8.0.0; SM-G955U Bu...
# 2  Mozilla/5.0 (compatible; AhrefsBot/7.0; +http:...
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2 like M...
# 4  Mozilla/5.0 (compatible; AhrefsBot/7.0; +http:...
#
#   js_fingerprint_profile_vendor tls_tls_version_record  \
# 0                                                  771
# 1                   Google Inc.                    771
# 2                   Google Inc.                    771
# 3          Apple Computer, Inc.                    771
# 4                   Google Inc.                    771
#
#   tls_tls_version_negotiated  \
# 0                        772
# 1                        772
# 2                        772
# 3                        772
# 4                        772
#
#                                              tls_ja3  \
# 0  771,4865-4867-4866-49195-49199-52393-52392-491...
# 1  771,4865-4866-4867-49195-49199-49196-49200-523...
# 2  771,4865-4866-4867-49195-49199-49196-49200-523...
# 3  771,4865-4866-4867-49196-49195-52393-49200-491...
# 4  771,4865-4866-4867-49195-49199-49196-49200-523...
#
#                        tls_ja3_hash                tls_peetprint_hash  \
# 0  c279b0189edb9269da7bc43dea5e0c36  fea33d3783ae74d495240377b44baa68
# 1  c9c72924ce9126d09d6688ee2c2b462b  8ad9325e12f531d2983b78860de7b0ec
# 2  9f8f0d3c82a11de7092c04dabcc909ac  d3adf83b0154a3dce2a78ec296fcbfa4
# 3  773906b0efdefa24a7f2b8eb6985bf37  b2bafdc69377086c3416be278fd21121
# 4  043bb5082ab9efb57fa102f13a86a6e0  d3adf83b0154a3dce2a78ec296fcbfa4
#
#                             http2_akamai_fingerprint  \
# 0  1:65536,4:131072,5:16384|12517377|3:0:0:201,5:...
# 1  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 2  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 3             2:0,4:2097152,3:100|10485760|0|m,s,p,a
# 4  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
#
#                                    http2_sent_frames  tcpip_ip_ttl  \
# 0  [HEADER_TABLE_SIZE = 65536, INITIAL_WINDOW_SIZ...          45.0
# 1  [HEADER_TABLE_SIZE = 65536, ENABLE_PUSH = 0, I...          46.0
# 2  [HEADER_TABLE_SIZE = 65536, ENABLE_PUSH = 0, I...          58.0
# 3  [ENABLE_PUSH = 0, INITIAL_WINDOW_SIZE = 209715...          48.0
# 4  [HEADER_TABLE_SIZE = 65536, ENABLE_PUSH = 0, I...          58.0
#
#    tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 0         1460.0           64240.0                 Linux
# 1         1366.0           59220.0                 Linux
# 2         1460.0           65535.0               Android
# 3         1412.0           65535.0                   iOS
# 4         1460.0           65535.0               Android
#
#   os_prediction_platform_mismatch  \
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
#
#                               tls_supported_versions
# 0                                 [TLS 1.3, TLS 1.2]
# 1            [TLS_GREASE (0x8a8a), TLS 1.3, TLS 1.2]
# 2            [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]
# 3  [TLS_GREASE (0x3a3a), TLS 1.3, TLS 1.2, TLS 1....
# 4            [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]

# %%
df = df.copy()
df.dropna(inplace= True)
print(df.isna().sum())
print(df.shape)
# Out:
# user_agent                         0
# js_fingerprint_profile_vendor      0
# tls_tls_version_record             0
# tls_tls_version_negotiated         0
# tls_ja3                            0
# tls_ja3_hash                       0
# tls_peetprint_hash                 0
# http2_akamai_fingerprint           0
# http2_sent_frames                  0
# tcpip_ip_ttl                       0
# tcpip_tcp_mss                      0
# tcpip_tcp_window                   0
# os_prediction_highest              0
# os_prediction_platform_mismatch    0
# tls_supported_versions             0
# dtype: int64
# (3623, 15)

# %%
columns_str = [
    "user_agent",
    "js_fingerprint_profile_vendor",
    "tls_ja3",
    "tls_ja3_hash",
    "tls_peetprint_hash",
    "http2_akamai_fingerprint",
    "os_prediction_highest"
]
columns_numeric = [
    "tls_tls_version_record",
    "tls_tls_version_negotiated"
]

df[columns_numeric] = df[columns_numeric].apply(pd.to_numeric)
print(df.dtypes)
# Out:
# user_agent                          object
# js_fingerprint_profile_vendor       object
# tls_tls_version_record               int64
# tls_tls_version_negotiated           int64
# tls_ja3                             object
# tls_ja3_hash                        object
# tls_peetprint_hash                  object
# http2_akamai_fingerprint            object
# http2_sent_frames                   object
# tcpip_ip_ttl                       float64
# tcpip_tcp_mss                      float64
# tcpip_tcp_window                   float64
# os_prediction_highest               object
# os_prediction_platform_mismatch     object
# tls_supported_versions              object
# dtype: object

# %%
display(df[df.loc[:, "os_prediction_platform_mismatch"] == 0])
# Out:
#                                             user_agent  \
# 193  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#     js_fingerprint_profile_vendor  tls_tls_version_record  \
# 193                   Google Inc.                     771
#
#      tls_tls_version_negotiated  \
# 193                         772
#
#                                                tls_ja3  \
# 193  771,4865-4866-4867-49195-49199-49196-49200-523...
#
#                          tls_ja3_hash                tls_peetprint_hash  \
# 193  0d69ff451640d67ee8b5122752834766  a0468212376b470d0ee57e6922986be3
#
#                               http2_akamai_fingerprint  \
# 193  1:65536,3:1000,4:6291456,6:262144|15663105|0|m...
#
#                                      http2_sent_frames  tcpip_ip_ttl  \
# 193  [HEADER_TABLE_SIZE = 65536, MAX_CONCURRENT_STR...          56.0
#
#      tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 193         1460.0           29200.0               Windows
#
#     os_prediction_platform_mismatch                   tls_supported_versions
# 193                           False  [TLS_GREASE (0x1a1a), TLS 1.3, TLS 1.2]

# %%
df.drop(index=193, inplace = True)

# %%
display(df.head(10))
df.to_csv('../clean_data/notebooks.csv')
df.to_json('../clean_data/notebooks.json')
# Out:
#                                           user_agent  \
# 0  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109...
# 1  Mozilla/5.0 (Linux; Android 8.0.0; SM-G955U Bu...
# 2  Mozilla/5.0 (compatible; AhrefsBot/7.0; +http:...
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2 like M...
# 4  Mozilla/5.0 (compatible; AhrefsBot/7.0; +http:...
# 5  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 6  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...
# 7  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...
# 8  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 9  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#   js_fingerprint_profile_vendor  tls_tls_version_record  \
# 0                                                   771
# 1                   Google Inc.                     771
# 2                   Google Inc.                     771
# 3          Apple Computer, Inc.                     771
# 4                   Google Inc.                     771
# 5                   Google Inc.                     771
# 6          Apple Computer, Inc.                     771
# 7          Apple Computer, Inc.                     771
# 8                   Google Inc.                     771
# 9                   Google Inc.                     771
#
#    tls_tls_version_negotiated  \
# 0                         772
# 1                         772
# 2                         772
# 3                         772
# 4                         772
# 5                         772
# 6                         772
# 7                         772
# 8                         772
# 9                         772
#
#                                              tls_ja3  \
# 0  771,4865-4867-4866-49195-49199-52393-52392-491...
# 1  771,4865-4866-4867-49195-49199-49196-49200-523...
# 2  771,4865-4866-4867-49195-49199-49196-49200-523...
# 3  771,4865-4866-4867-49196-49195-52393-49200-491...
# 4  771,4865-4866-4867-49195-49199-49196-49200-523...
# 5  771,4865-4866-4867-49195-49199-49196-49200-523...
# 6  771,4865-4866-4867-49196-49195-52393-49200-491...
# 7  771,4865-4866-4867-49196-49195-52393-49200-491...
# 8  771,4865-4866-4867-49195-49199-49196-49200-523...
# 9  771,4865-4866-4867-49195-49199-49196-49200-523...
#
#                        tls_ja3_hash                tls_peetprint_hash  \
# 0  c279b0189edb9269da7bc43dea5e0c36  fea33d3783ae74d495240377b44baa68
# 1  c9c72924ce9126d09d6688ee2c2b462b  8ad9325e12f531d2983b78860de7b0ec
# 2  9f8f0d3c82a11de7092c04dabcc909ac  d3adf83b0154a3dce2a78ec296fcbfa4
# 3  773906b0efdefa24a7f2b8eb6985bf37  b2bafdc69377086c3416be278fd21121
# 4  043bb5082ab9efb57fa102f13a86a6e0  d3adf83b0154a3dce2a78ec296fcbfa4
# 5  0d69ff451640d67ee8b5122752834766  052336488e42ad64eb9768f5bc03004a
# 6  773906b0efdefa24a7f2b8eb6985bf37  b2bafdc69377086c3416be278fd21121
# 7  773906b0efdefa24a7f2b8eb6985bf37  b2bafdc69377086c3416be278fd21121
# 8  cd08e31494f9531f560d64c695473da9  22a4f858cc83b9144c829ca411948a88
# 9  cd08e31494f9531f560d64c695473da9  22a4f858cc83b9144c829ca411948a88
#
#                             http2_akamai_fingerprint  \
# 0  1:65536,4:131072,5:16384|12517377|3:0:0:201,5:...
# 1  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 2  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 3             2:0,4:2097152,3:100|10485760|0|m,s,p,a
# 4  1:65536,2:0,4:6291456,6:262144|15663105|0|m,a,s,p
# 5  1:65536,3:1000,4:6291456,6:262144|15663105|0|m...
# 6             2:0,4:2097152,3:100|10485760|0|m,s,p,a
# 7             2:0,4:2097152,3:100|10485760|0|m,s,p,a
# 8  1:65536,2:0,3:1000,4:6291456,6:262144|15663105...
# 9  1:65536,2:0,3:1000,4:6291456,6:262144|15663105...
#
#                                    http2_sent_frames  tcpip_ip_ttl  \
# 0  [HEADER_TABLE_SIZE = 65536, INITIAL_WINDOW_SIZ...          45.0
# 1  [HEADER_TABLE_SIZE = 65536, ENABLE_PUSH = 0, I...          46.0
# 2  [HEADER_TABLE_SIZE = 65536, ENABLE_PUSH = 0, I...          58.0
# 3  [ENABLE_PUSH = 0, INITIAL_WINDOW_SIZE = 209715...          48.0
# 4  [HEADER_TABLE_SIZE = 65536, ENABLE_PUSH = 0, I...          58.0
# 5  [HEADER_TABLE_SIZE = 65536, MAX_CONCURRENT_STR...          55.0
# 6  [ENABLE_PUSH = 0, INITIAL_WINDOW_SIZE = 209715...          53.0
# 7  [ENABLE_PUSH = 0, INITIAL_WINDOW_SIZE = 209715...          53.0
# 8  [HEADER_TABLE_SIZE = 65536, ENABLE_PUSH = 0, M...          45.0
# 9  [HEADER_TABLE_SIZE = 65536, ENABLE_PUSH = 0, M...          45.0
#
#    tcpip_tcp_mss  tcpip_tcp_window os_prediction_highest  \
# 0         1460.0           64240.0                 Linux
# 1         1366.0           59220.0                 Linux
# 2         1460.0           65535.0               Android
# 3         1412.0           65535.0                   iOS
# 4         1460.0           65535.0               Android
# 5         1420.0           65320.0                 Linux
# 6         1460.0           65535.0                   iOS
# 7         1460.0           65535.0                   iOS
# 8         1460.0           64240.0                 Linux
# 9         1460.0           64240.0                 Linux
#
#   os_prediction_platform_mismatch  \
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
# 5                            True
# 6                            True
# 7                            True
# 8                            True
# 9                            True
#
#                               tls_supported_versions
# 0                                 [TLS 1.3, TLS 1.2]
# 1            [TLS_GREASE (0x8a8a), TLS 1.3, TLS 1.2]
# 2            [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]
# 3  [TLS_GREASE (0x3a3a), TLS 1.3, TLS 1.2, TLS 1....
# 4            [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]
# 5  [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2, TLS 1....
# 6  [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2, TLS 1....
# 7  [TLS_GREASE (0x8a8a), TLS 1.3, TLS 1.2, TLS 1....
# 8            [TLS_GREASE (0x1a1a), TLS 1.3, TLS 1.2]
# 9            [TLS_GREASE (0x5a5a), TLS 1.3, TLS 1.2]
